# %% [markdown]
# # Q4_PART ONE
# You are supposed to extract data from the awards column in this dataset and split it into several
# columns

# %%
import pandas as pd
from pandas import DataFrame
import sys, os, datetime

# %%
path = os.getcwd()+'\\data\\movies_awards.csv'
path
# Out:
# 'C:\\Users\\ninad\\LocalRepository\\gadre_ninad_spring2017\\Assignment No 03\\data\\movies_awards.csv'

# %%
df = pd.read_csv(path) #Read data from CSV

# %%
df.head()
# Out:
#   totalSeasons                                               Plot Rated  \
# 0         none                                                NaN   NaN
# 1         none                                                NaN   NaN
# 2         none                                                NaN   NaN
# 3         none  A historical classic drama in three acts; reto...   NaN
# 4         none  A father (Williams) suspects his son (Jackson)...     R
#
#   Response    Language                                              Title  \
# 0     True     English  Book of Love: The Definitive Reason Why Men Ar...
# 1     True     Swedish                              Anderssons älskarinna
# 2     True     English                                          Bad Blood
# 3     True  Portuguese                                       Who Are You?
# 4     True     English                            Skeletons in the Closet
#
#     Country                                Writer  Metascore  imdbRating  \
# 0       USA          Jeffrey W. Byrd; Eric George        NaN         6.6
# 1    Sweden                                   NaN        NaN         7.4
# 2        UK                         Tony Marchant        NaN         5.6
# 3  Portugal  João Botelho; Almeida Garrett (play)        NaN         6.1
# 4       USA            Donna Powers; Wayne Powers        NaN         5.4
#
#      ...         Released                                             Actors  \
# 0    ...      14 Feb 2002  40 Glocc; Angelle Brooks; David Brown; Qadr Ca...
# 1    ...      12 Feb 2001  Jakob Eklund; Ebba Forsberg; Örjan Landström; ...
# 2    ...      11 Jan 2001  Emilia Fox; Serban Celea; Alex Jennings; Steve...
# 3    ...      23 Nov 2001  Patrícia Guerreiro; Suzana Borges; Rui Morisso...
# 4    ...      24 Jul 2001  Treat Williams; Linda Hamilton; Jonathan Jacks...
#
#    Year                  Genre                  Awards  Runtime   Type  \
# 0  2002        Romance; Comedy                     NaN   91 min  movie
# 1  2001                  Drama                     NaN  347 min  movie
# 2  2001                    NaN                     NaN      NaN  movie
# 3  2001         Drama; History  1 win & 2 nominations.  112 min  movie
# 4  2001  Crime; Drama; Mystery                  1 win.  100 min  movie
#
#                                               Poster imdbVotes     imdbID
# 0                                                NaN      79.0  tt0156376
# 1                                                NaN      34.0  tt0201374
# 2                                                NaN       8.0  tt0207989
# 3  http://ia.media-imdb.com/images/M/MV5BMTM1Mjdi...     189.0  tt0210930
# 4  http://ia.media-imdb.com/images/M/MV5BMjA0NjA2...     603.0  tt0212513
#
# [5 rows x 21 columns]

# %%
df = df[df['Awards'].notnull()]
df['Awards_won'] = df['Awards'].str.extract('(\d+) win', expand=True)
df['Awards_nominated'] = df['Awards'].str.extract('(\d+) nomination', expand=True)

# %%
#function to take plurals into count
def strip_plural(title):
    if str(title).endswith('s'):
        return str(title)[:-1]
    else:
        return str(title)

# %%
#extract name and count of award
df[['AwardCount','AwardWon']] = df['Awards'].str.extract('Won (\d+) (.*). Another', expand=True)
#extract name and count of nomination
df[['NominatedCount','AwardNominated']]= df['Awards'].str.extract('Nominated for (\d+) (.*). Another', expand=True)

# %%
df['AwardWon']= df['AwardWon'].apply(lambda x: strip_plural(x))
df['AwardNominated']= df['AwardNominated'].apply(lambda x: strip_plural(x))

# %%
#drop all duplicate entries
df = df.drop_duplicates()
df1 = df[['imdbID','AwardWon','AwardCount']]
df1 = df1.pivot(index = 'imdbID', columns='AwardWon', values='AwardWon').drop(['nan'],1)
df1 = df1.add_suffix('_won')

# %%
df2 = df[['imdbID','AwardNominated','NominatedCount']]
df2 = df2.pivot(index = 'imdbID', columns='AwardNominated', values='AwardNominated').drop(['nan'],1)
df2 = df2.add_suffix('_nominated')

# %%
df3 = pd.concat([df1,df2],axis =1)
df.head()
# Out:
#   totalSeasons                                               Plot Rated  \
# 3         none  A historical classic drama in three acts; reto...   NaN
# 4         none  A father (Williams) suspects his son (Jackson)...     R
# 5         none  Four perky; clueless cheerleaders from the Hap...     R
# 6         none  Sandrine; a woman in her thirties gets tired o...   NaN
# 7         none  A rivalry develops between a showbiz veteran a...     R
#
#   Response    Language                    Title   Country  \
# 3     True  Portuguese             Who Are You?  Portugal
# 4     True     English  Skeletons in the Closet       USA
# 5     True     English       Cheerleader Ninjas       USA
# 6     True      French      The Girl from Paris    France
# 7     True     English        The Final Curtain   UK; USA
#
#                                  Writer  Metascore  imdbRating  \
# 3  João Botelho; Almeida Garrett (play)        NaN         6.1
# 4            Donna Powers; Wayne Powers        NaN         5.4
# 5                        Kevin Campbell        NaN         2.3
# 6         Christian Carion; Eric Assous       64.0         6.8
# 7                            John Hodge        NaN         5.8
#
#         ...         Type                                             Poster  \
# 3       ...        movie  http://ia.media-imdb.com/images/M/MV5BMTM1Mjdi...
# 4       ...        movie  http://ia.media-imdb.com/images/M/MV5BMjA0NjA2...
# 5       ...        movie  http://ia.media-imdb.com/images/M/MV5BMjA3MTQ1...
# 6       ...        movie  https://images-na.ssl-images-amazon.com/images...
# 7       ...        movie  http://ia.media-imdb.com/images/M/MV5BOGI4MmIw...
#
#   imdbVotes     imdbID Awards_won Awards_nominated AwardCount AwardWon  \
# 3     189.0  tt0210930          1                2        NaN      nan
# 4     603.0  tt0212513          1              NaN        NaN      nan
# 5     881.0  tt0235280        NaN                1        NaN      nan
# 6    1715.0  tt0240149          3                2        NaN      nan
# 7     466.0  tt0243904          1                1        NaN      nan
#
#   NominatedCount  AwardNominated
# 3            NaN             nan
# 4            NaN             nan
# 5            NaN             nan
# 6            NaN             nan
# 7            NaN             nan
#
# [5 rows x 27 columns]

# %%
df4 = df[['imdbID','Title','Awards','Awards_won','AwardCount','Awards_nominated','NominatedCount']].sort_values(by='imdbID')
df4.set_index('imdbID',inplace=True)
result_df = df4.join(df3, how='inner')
result_df.head()
# Out:
#                                         Title  \
# imdbID
# tt0038650               It's a Wonderful Life
# tt0062622               2001: A Space Odyssey
# tt0070992                          Happy Days
# tt0076759  Star Wars: Episode IV - A New Hope
# tt0077687                          The Hobbit
#
#                                                       Awards Awards_won  \
# imdbID
# tt0038650  Nominated for 5 Oscars. Another 6 wins & 1 nom...          6
# tt0062622      Won 1 Oscar. Another 13 wins & 7 nominations.         13
# tt0070992  Won 3 Golden Globes. Another 13 wins & 19 nomi...         13
# tt0076759    Won 6 Oscars. Another 48 wins & 28 nominations.         48
# tt0077687                             1 win & 2 nominations.          1
#
#           AwardCount Awards_nominated NominatedCount Golden Globe_won  \
# imdbID
# tt0038650        NaN                1              5             None
# tt0062622          1                7            NaN             None
# tt0070992          3               19            NaN     Golden Globe
# tt0076759          6               28            NaN             None
# tt0077687        NaN                2            NaN             None
#
#           Oscar_won Primetime Emmy_won BAFTA Film Award_nominated  \
# imdbID
# tt0038650      None               None                       None
# tt0062622     Oscar               None                       None
# tt0070992      None               None                       None
# tt0076759     Oscar               None                       None
# tt0077687      None               None                       None
#
#           Golden Globe_nominated Oscar_nominated Primetime Emmy_nominated
# imdbID
# tt0038650                   None           Oscar                     None
# tt0062622                   None            None                     None
# tt0070992                   None            None                     None
# tt0076759                   None            None                     None
# tt0077687                   None            None                     None

# %%
result_df = result_df.fillna(0)

# %%
#calculate total awards won for each movie
result_df['Awards_won'] = result_df['Awards_won'].astype(int) + result_df['AwardCount'].astype(int)
#calculate total nominations
result_df['Awards_nominated'] = result_df['Awards_nominated'].astype(int) + result_df['NominatedCount'].astype(int)

# %%
result_df = result_df.drop(['AwardCount','NominatedCount'], axis =1)   
result_df.head()
# Out:
#                                         Title  \
# imdbID
# tt0038650               It's a Wonderful Life
# tt0062622               2001: A Space Odyssey
# tt0070992                          Happy Days
# tt0076759  Star Wars: Episode IV - A New Hope
# tt0077687                          The Hobbit
#
#                                                       Awards  Awards_won  \
# imdbID
# tt0038650  Nominated for 5 Oscars. Another 6 wins & 1 nom...           6
# tt0062622      Won 1 Oscar. Another 13 wins & 7 nominations.          14
# tt0070992  Won 3 Golden Globes. Another 13 wins & 19 nomi...          16
# tt0076759    Won 6 Oscars. Another 48 wins & 28 nominations.          54
# tt0077687                             1 win & 2 nominations.           1
#
#            Awards_nominated Golden Globe_won Oscar_won Primetime Emmy_won  \
# imdbID
# tt0038650                 6                0         0                  0
# tt0062622                 7                0     Oscar                  0
# tt0070992                19     Golden Globe         0                  0
# tt0076759                28                0     Oscar                  0
# tt0077687                 2                0         0                  0
#
#           BAFTA Film Award_nominated Golden Globe_nominated Oscar_nominated  \
# imdbID
# tt0038650                          0                      0           Oscar
# tt0062622                          0                      0               0
# tt0070992                          0                      0               0
# tt0076759                          0                      0               0
# tt0077687                          0                      0               0
#
#           Primetime Emmy_nominated
# imdbID
# tt0038650                        0
# tt0062622                        0
# tt0070992                        0
# tt0076759                        0
# tt0077687                        0

# %%
result_df.to_csv('Ques04.csv',sep=',', index=False)
