# %% [markdown]
# # Q2_PART TWO
# Display the top 5 Job Families according to this percentage value

# %%
import pandas as pd
from pandas import DataFrame
import sys, os, datetime

# %%
path = os.getcwd()+'\\data\\employee_compensation.csv'
path
# Out:
# 'C:\\Users\\ninad\\LocalRepository\\gadre_ninad_spring2017\\Assignment No 03\\data\\employee_compensation.csv'

# %%
df = pd.read_csv(path) #Read data from CSV

# %%
df.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 1    Fiscal  2015                        4
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 4    Fiscal  2015                        5
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 1                          Community Health             DPH
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 4                      Culture & Recreation             REC
#
#                           Department  Union Code  \
# 0                 Airport Commission        38.0
# 1                      Public Health       790.0
# 2  Department of the Status of Women       323.0
# 3                    Human Resources       790.0
# 4     Recreation and Park Commission       790.0
#
#                                 Union Job Family Code           Job Family  \
# 0  Plumbers and Pipefitters, Local 38            7300     Journeyman Trade
# 1    SEIU - Miscellaneous, Local 1021            2600       Dietary & Food
# 2   Members of Boards and Commissions            0900           Management
# 3    SEIU - Miscellaneous, Local 1021            8100        Legal & Court
# 4    SEIU - Miscellaneous, Local 1021            9900  Public Service Aide
#
#           ...         Employee Identifier  Salaries  Overtime  Other Salaries  \
# 0         ...                       52206  98528.52      0.00         3955.59
# 1         ...                       52950  69169.82    755.02         4179.08
# 2         ...                       33958    200.00      0.00            0.00
# 3         ...                       33073   1783.00      0.00            0.00
# 4         ...                       15849   1102.50      0.00            0.00
#
#    Total Salary  Retirement  Health/Dental  Other Benefits  Total Benefits  \
# 0     102484.11    20142.55       12918.24         8371.76        41432.55
# 1      74103.92    15641.92       12499.30         5669.02        33810.24
# 2        200.00        0.00          51.45           15.83           67.28
# 3       1783.00      325.05         257.23          153.85          736.13
# 4       1102.50        0.00         538.82           85.36          624.18
#
#    Total Compensation
# 0           143916.66
# 1           107914.16
# 2              267.28
# 3             2519.13
# 4             1726.68
#
# [5 rows x 22 columns]

# %%
df = df[df['Year Type'] == 'Calendar']
col = ['Year'] + list(df.loc[:,'Salaries':'Total Compensation'])
sal = df[col]

# %%
temp = []
for each in df['Year'].unique():
    year = sal[sal['Year'] == each]
    value = year.mean()
    temp.append((each,value['Salaries'],
               value['Overtime'],
               value['Other Salaries'],
               value['Total Salary'],
               value['Retirement'],
               value['Health/Dental'],
               value['Other Benefits'],
               value['Total Benefits'],
               value['Total Compensation']))
    
avg_comp = DataFrame(temp,columns=('Year',
                                   'Salaries',
                                  'Overtime',
                                  'Other Salaries',
                                   'Total Salary',
                                  'Retirement',
                                  'Health/Dental',
                                  'Other Benefits',
                                  'Total Benefits',
                                  'Total Compensation')).sort_values(by='Year').reset_index(drop=True)

avg_comp.head()
# Out:
#    Year      Salaries     Overtime  Other Salaries  Total Salary  \
# 0  2013  64717.640360  4349.412288     4066.732887  73133.785536
# 1  2014  62261.763051  4337.825321     3779.957193  70379.545565
# 2  2015  63801.845319  4494.442771     3641.294141  71937.582232
# 3  2016  68854.615528  5136.289255     3862.865007  77853.769790
#
#      Retirement  Health/Dental  Other Benefits  Total Benefits  \
# 0  12793.179458    9121.905413     4589.542170    26504.627042
# 1  13626.814387    9103.711882     4607.544801    27338.071070
# 2  13200.527822    8692.585989     4774.660678    26667.774489
# 3  12742.523146    9841.200363     5187.041823    27770.765331
#
#    Total Compensation
# 0        99638.412577
# 1        97717.616635
# 2        98605.356720
# 3       105624.535122

# %%
#overtime greater than 5%
df[df['Overtime'] > (df['Salaries']*0.05)].head()
# Out:
#    Year Type  Year  Organization Group Code  \
# 14  Calendar  2014                        5
# 23  Calendar  2016                        5
# 38  Calendar  2013                        2
# 40  Calendar  2015                        1
# 44  Calendar  2015                        1
#
#                          Organization Group Department Code  \
# 14                     Culture & Recreation             REC
# 23                     Culture & Recreation             FAM
# 38  Public Works, Transportation & Commerce             CWP
# 40                        Public Protection             POL
# 44                        Public Protection             FIR
#
#                         Department  Union Code  \
# 14  Recreation and Park Commission       261.0
# 23                Fine Arts Museum        39.0
# 38       PUC Wastewater Enterprise        39.0
# 40                          Police       911.0
# 44                 Fire Department       798.0
#
#                                       Union Job Family Code  \
# 14                      Laborers, Local 261            3400
# 23           Stationary Engineers, Local 39            7100
# 38           Stationary Engineers, Local 39            7300
# 40             Police Officers' Association            Q000
# 44  Firefighters - Miscellaneous, Local 798            H000
#
#                        Job Family         ...         Employee Identifier  \
# 14     Agriculture & Horticulture         ...                       23029
# 23  Administrative-Labor & Trades         ...                       20763
# 38               Journeyman Trade         ...                        8705
# 40                Police Services         ...                       13888
# 44                  Fire Services         ...                       38574
#
#      Salaries  Overtime  Other Salaries  Total Salary  Retirement  \
# 14   63978.00  17039.61         2184.23      83201.84    14287.99
# 23  133977.95  20699.15            0.00     154677.10    24039.10
# 38   86530.02  17962.95        10555.21     115048.18    18665.90
# 40  117139.22  20576.29         5747.49     143463.00    23170.33
# 44  130341.65  29607.28        16292.82     176241.75    28793.64
#
#     Health/Dental  Other Benefits  Total Benefits  Total Compensation
# 14       13054.95         6721.63        34064.57           117266.41
# 23       13890.30        10671.44        48600.84           203277.94
# 38       12918.24         9328.44        40912.58           155960.76
# 40       12424.51         2240.80        37835.64           181298.64
# 44       15052.76         2995.69        46842.09           223083.84
#
# [5 rows x 22 columns]

# %%
temp = []
for every in df['Job Family'].unique():
    benefits = df[df['Job Family'] == every]['Total Benefits'].mean()
    comp = df[df['Job Family'] == every]['Total Compensation'].mean()
    percent = (benefits/comp)*100
    temp.append((every,benefits,comp,percent))
    
percent_comp = DataFrame(temp,columns=('Job Family',
                                      'Total Benefits',
                                      'Total Compensation',
                                      'Percentage')).sort_values(by='Percentage',ascending=False).reset_index(drop=True)
percent_comp.head()
# Out:
#                       Job Family  Total Benefits  Total Compensation  \
# 0            Public Service Aide     5267.903671        14956.280236
# 1                     Park & Zoo    17946.662641        54776.310325
# 2         Housekeeping & Laundry    24286.767749        74189.739399
# 3  Clerical, Secretarial & Steno    21549.044311        66517.545454
# 4                 Dietary & Food    19673.743314        61537.993465
#
#    Percentage
# 0   35.222018
# 1   32.763548
# 2   32.736020
# 3   32.396030
# 4   31.970076

# %%
#write to csv
avg_comp.to_csv('Ques02_Part02.csv',index=False,header=True)
